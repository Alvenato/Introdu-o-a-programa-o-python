# %% [markdown]
# Esta atividade consiste em um sistema básico de gerenciamento de notas escolares desenvolvido em Python. O código utiliza estruturas de programação fundamentais para coletar dados, realizar cálculos e tomar decisões com base em condições predefinidas.

# %%
Amigos = []
while True:
    nome = input("Digite o nome do amigo (ou 'sair' para encerrar): ")
    if nome.lower() == 'sair':
        break
    Amigos.append(nome)
    telefone = int(input("Digite o telefone do amigo: "))
    Amigos.append(telefone)
    lista = [nome, telefone]
    print("Amigo adicionado:", lista)
# Out:
# Amigo adicionado: ['Eduarda', 61981830780]
# Amigo adicionado: ['Joana', 61985758541]
# Amigo adicionado: ['Pedro', 6198987585]
