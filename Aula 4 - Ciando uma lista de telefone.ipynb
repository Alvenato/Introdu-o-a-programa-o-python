# %% [markdown]
# Esta atividade consiste em um sistema básico de gerenciamento de notas escolares desenvolvido em Python. O código utiliza estruturas de programação fundamentais para coletar dados, realizar cálculos e tomar decisões com base em condições predefinidas.

# %%
catalogo = {
    "Eduarda":("61982625389"),
    "Maria":("61982625389"),
    "João":("61982625389"),
    "Pedro":("61982625389"),
    "Jesus":("77777777777")
}
for i in catalogo:
    print(i, end= ' - ')
    for j in catalogo[i]:
        print(j, end= ' ')
    print()
# Out:
# Eduarda - 6 1 9 8 2 6 2 5 3 8 9
# Maria - 6 1 9 8 2 6 2 5 3 8 9
# João - 6 1 9 8 2 6 2 5 3 8 9
# Pedro - 6 1 9 8 2 6 2 5 3 8 9
# Jesus - 7 7 7 7 7 7 7 7 7 7 7
